# %%
import pandas as pd

# Load the dataset (assuming CSV file)
data = pd.read_csv('AAPL_50_years_stock_data.csv', parse_dates=['Date'])

# Display the first few rows
print(data.head())
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1980-12-12 00:00:00-05:00  0.098834  0.099264  0.098834  0.098834
# 1  1980-12-15 00:00:00-05:00  0.094108  0.094108  0.093678  0.093678
# 2  1980-12-16 00:00:00-05:00  0.087232  0.087232  0.086802  0.086802
# 3  1980-12-17 00:00:00-05:00  0.088951  0.089381  0.088951  0.088951
# 4  1980-12-18 00:00:00-05:00  0.091530  0.091959  0.091530  0.091530
#
#       Volume  Dividends  Stock Splits
# 0  469033600        0.0           0.0
# 1  175884800        0.0           0.0
# 2  105728000        0.0           0.0
# 3   86441600        0.0           0.0
# 4   73449600        0.0           0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("AAPL_50_years_stock_data.csv")
df
# Out:
#                             Date        Open        High         Low  \
# 0      1980-12-12 00:00:00-05:00    0.098834    0.099264    0.098834
# 1      1980-12-15 00:00:00-05:00    0.094108    0.094108    0.093678
# 2      1980-12-16 00:00:00-05:00    0.087232    0.087232    0.086802
# 3      1980-12-17 00:00:00-05:00    0.088951    0.089381    0.088951
# 4      1980-12-18 00:00:00-05:00    0.091530    0.091959    0.091530
# ...                          ...         ...         ...         ...
# 11098  2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002
# 11099  2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997
# 11100  2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993
# 11101  2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005
# 11102  2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998
#
#             Close     Volume  Dividends  Stock Splits
# 0        0.098834  469033600        0.0           0.0
# ...

# %%
missing_values=df.isnull().sum()
print(missing_values)
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
df_no_duplicates=df.drop_duplicates()

# %%
df.head()
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1980-12-12 00:00:00-05:00  0.098834  0.099264  0.098834  0.098834
# 1  1980-12-15 00:00:00-05:00  0.094108  0.094108  0.093678  0.093678
# 2  1980-12-16 00:00:00-05:00  0.087232  0.087232  0.086802  0.086802
# 3  1980-12-17 00:00:00-05:00  0.088951  0.089381  0.088951  0.088951
# 4  1980-12-18 00:00:00-05:00  0.091530  0.091959  0.091530  0.091530
#
#       Volume  Dividends  Stock Splits
# 0  469033600        0.0           0.0
# 1  175884800        0.0           0.0
# 2  105728000        0.0           0.0
# 3   86441600        0.0           0.0
# 4   73449600        0.0           0.0

# %%
df.tail()
# Out:
#                             Date        Open        High         Low  \
# 11098  2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002
# 11099  2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997
# 11100  2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993
# 11101  2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005
# 11102  2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998
#
#             Close     Volume  Dividends  Stock Splits
# 11098  254.490005  147495300        0.0           0.0
# 11099  255.270004   40858800        0.0           0.0
# 11100  258.200012   23234700        0.0           0.0
# 11101  259.019989   27237100        0.0           0.0
# 11102  255.589996   42317100        0.0           0.0

# %%
# Check if all Dividends and Stock Splits are zero
are_dividends_zero = (data['Dividends'] == 0).all()
are_splits_zero = (data['Stock Splits'] == 0).all()

if are_dividends_zero:
    print("All Dividend values are zero.")
else:
    print("There are non-zero Dividend values.")

if are_splits_zero:
    print("All Stock Split values are zero.")
else:
    print("There are non-zero Stock Split values.")
# Out:
# There are non-zero Dividend values.
# There are non-zero Stock Split values.

# %%
non_zero_dividends = data[data['Dividends'] != 0]
non_zero_splits = data[data['Stock Splits'] != 0]

print("Non-zero Dividend rows:")
print(non_zero_dividends)

print("Non-zero Stock Split rows:")
print(non_zero_splits)
# Out:
# Non-zero Dividend rows:
#                             Date        Open        High         Low  \
# 1619   1987-05-11 00:00:00-04:00    0.265108    0.273715    0.264247
# 1682   1987-08-10 00:00:00-04:00    0.332675    0.332675    0.315438
# 1752   1987-11-17 00:00:00-05:00    0.253937    0.255664    0.241845
# 1812   1988-02-12 00:00:00-05:00    0.281266    0.287325    0.280401
# 1876   1988-05-16 00:00:00-04:00    0.280956    0.287026    0.277487
# ...                          ...         ...         ...         ...
# 10819  2023-11-10 00:00:00-05:00  183.073126  185.660457  182.635268
# 10880  2024-02-09 00:00:00-05:00  187.969837  189.305018  187.322187
# 10943  2024-05-10 00:00:00-04:00  184.483257  184.672831  181.719511
# 11006  2024-08-12 00:00:00-04:00  215.832552  219.268759  215.363068
# 11069  2024-11-08 00:00:00-05:00  227.169998  228.660004  226.410004
#
#             Close     Volume  Dividends  Stock Splits
# 1619     0.265108  197276800   0.000536           0.0
# ...

# %%
data['Adjusted Close'] = data['Close'] / data['Stock Splits'].replace(0, 1).cumprod()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('AAPL Stock Price Over Time')
plt.legend()
plt.show()

# %%
total_dividends = data['Dividends'].sum()
print(f"Total Dividends Paid: {total_dividends}")
# Out:
# Total Dividends Paid: 8.773563999999999

# %%
total_splits = data['Stock Splits'].sum()
print(f"Total Stock Splits: {total_splits}")
# Out:
# Total Stock Splits: 17.0

# %%
data.to_csv('Processed_Stock_Data.csv', index=False)
print("Processed data saved to 'Processed_Stock_Data.csv'")
# Out:
# Processed data saved to 'Processed_Stock_Data.csv'

# %%
df=pd.read_csv("Processed_Stock_Data.csv")
df
# Out:
#                             Date        Open        High         Low  \
# 0      1980-12-12 00:00:00-05:00    0.098834    0.099264    0.098834
# 1      1980-12-15 00:00:00-05:00    0.094108    0.094108    0.093678
# 2      1980-12-16 00:00:00-05:00    0.087232    0.087232    0.086802
# 3      1980-12-17 00:00:00-05:00    0.088951    0.089381    0.088951
# 4      1980-12-18 00:00:00-05:00    0.091530    0.091959    0.091530
# ...                          ...         ...         ...         ...
# 11098  2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002
# 11099  2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997
# 11100  2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993
# 11101  2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005
# 11102  2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998
#
#             Close     Volume  Dividends  Stock Splits  Adjusted Close
# ...

# %%
df = df.sort_index()

# Display the DataFrame structure
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11103 entries, 0 to 11102
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            11103 non-null  object
#  1   Open            11103 non-null  float64
#  2   High            11103 non-null  float64
#  3   Low             11103 non-null  float64
#  4   Close           11103 non-null  float64
#  5   Volume          11103 non-null  int64
#  6   Dividends       11103 non-null  float64
#  7   Stock Splits    11103 non-null  float64
#  8   Adjusted Close  11103 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 780.8+ KB
# None

# %%
target = df['Adjusted Close']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(target, label='Adjusted Close')
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
